# %% [markdown]
# # Model 2
# ### 2 layer LSTM
#
# 2018-11-14
#
# uses Nvidia Tesla P100 GPU
# uses .to(device)
#
# ***

# %% [markdown]
# ### Hyperparameters
#
# 1. seqeuence_len / n_word = 512 (previous: 128)
# 2. batch_size / n_seq = 128
# 3. hidden_dim = 512
# 4. top_k words = 3 (previous: 5)
# 5. predict seq_len = 512 (previous: 1024)
# 6. epoch = 300
#
#
# 1. log every 100 batches
# 2. save model every 20 epochs
#
# ***

# %%
import numpy as np

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

import keras
from keras.utils import to_categorical

import time
# Out:
# Using TensorFlow backend.

# %%
dtype = torch.float
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Assume that we are on a CUDA machine, then this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %%
# replace with any text file containing full set of data
music_data = 'txt-files/notewise/beethoven.txt'

with open(music_data, 'r') as file:
    text = file.read()

# %%
# get vocabulary set
words = sorted(tuple(set(text.split())))
n = len(words)

# create word-integer encoder/decoder
word2int = dict(zip(words, list(range(n))))
int2word = dict(zip(list(range(n)), words))

# encode all words in dataset into integers
encoded = np.array([word2int[word] for word in text.split()])

# %%
# define model using the pytorch nn module
class WordLSTM(nn.ModuleList):
    
    def __init__(self, sequence_len, vocab_size, hidden_dim, batch_size):
        super(WordLSTM, self).__init__()
        
        # init the hyperparameters
        self.vocab_size = vocab_size
        self.sequence_len = sequence_len
        self.batch_size = batch_size
        self.hidden_dim = hidden_dim
        
        # first layer lstm cell
        self.lstm_1 = nn.LSTMCell(input_size=vocab_size, hidden_size=hidden_dim)
        
        # second layer lstm cell
        self.lstm_2 = nn.LSTMCell(input_size=hidden_dim, hidden_size=hidden_dim)
        
        # dropout layer
        self.dropout = nn.Dropout(p=0.5)
        
        # fully connected layer
        self.fc = nn.Linear(in_features=hidden_dim, out_features=vocab_size)
        
    # forward pass in training   
    def forward(self, x, hc):
        """
            accepts 2 arguments: 
            1. x: input of each batch 
                - shape 128*149 (batch_size*vocab_size)
            2. hc: tuple of init hidden, cell states 
                - each of shape 128*512 (batch_size*hidden_dim)
        """
        
        # create empty output seq
        output_seq = torch.empty((self.sequence_len,
                                  self.batch_size,
                                  self.vocab_size))
        # if using gpu        
        output_seq = output_seq.to(device)
        
        # init hidden, cell states for lstm layers
        hc_1, hc_2 = hc, hc
        
        # for t-th word in every sequence 
        for t in range(self.sequence_len):
            
            # layer 1 lstm
            hc_1 = self.lstm_1(x[t], hc_1)
            h_1, c_1 = hc_1
            
            # layer 2 lstm
            hc_2 = self.lstm_2(h_1, hc_2)
            h_2, c_2 = hc_2
            
            # dropout and fully connected layer
            output_seq[t] = self.fc(self.dropout(h_2))
            
        return output_seq.view((self.sequence_len * self.batch_size, -1))
          
    def init_hidden(self):
        
        # initialize hidden, cell states for training
        # if using gpu
        return (torch.zeros(self.batch_size, self.hidden_dim).to(device),
                torch.zeros(self.batch_size, self.hidden_dim).to(device))
    
    def init_hidden_generator(self):
        
        # initialize hidden, cell states for prediction of 1 sequence
        # if using gpu
        return (torch.zeros(1, self.hidden_dim).to(device),
                torch.zeros(1, self.hidden_dim).to(device))
    
    def predict(self, seed_seq, top_k=5, pred_len=128):
        """
            accepts 3 arguments: 
            1. seed_seq: seed string sequence for prediction (prompt)
            2. top_k: top k words to sample prediction from
            3. pred_len: number of words to generate after the seed seq
        """
        
        # set evaluation mode
        self.eval()
        
        # split string into list of words
        seed_seq = seed_seq.split()
        
        # get seed sequence length
        seed_len = len(seed_seq)
        
        # create output sequence
        out_seq = np.empty(seed_len+pred_len)
        
        # append input seq to output seq
        out_seq[:seed_len] = np.array([word2int[word] for word in seed_seq])
 
        # init hidden, cell states for generation
        hc = self.init_hidden_generator()
        hc_1, hc_2 = hc, hc
        
        # feed seed string into lstm
        # get the hidden state set up
        for word in seed_seq[:-1]:
            
            # encode starting word to one-hot encoding
            word = to_categorical(word2int[word], num_classes=self.vocab_size)

            # add batch dimension
            word = torch.from_numpy(word).unsqueeze(0)
            # if using gpu
            word = word.to(device) 
            
            # layer 1 lstm
            hc_1 = self.lstm_1(word, hc_1)
            h_1, c_1 = hc_1
            
            # layer 2 lstm
            hc_2 = self.lstm_2(h_1, hc_2)
            h_2, c_2 = hc_2
        
        word = seed_seq[-1]
        
        # encode starting word to one-hot encoding
        word = to_categorical(word2int[word], num_classes=self.vocab_size)

        # add batch dimension
        word = torch.from_numpy(word).unsqueeze(0)
        # if using gpu
        word = word.to(device) 

        # forward pass
        for t in range(pred_len):
            
            # layer 1 lstm
            hc_1 = self.lstm_1(word, hc_1)
            h_1, c_1 = hc_1
            
            # layer 2 lstm
            hc_2 = self.lstm_2(h_1, hc_2)
            h_2, c_2 = hc_2
            
            # fully connected layer without dropout (no need)
            output = self.fc(h_2)
            
            # software to get probabilities of output options
            output = F.softmax(output, dim=1)
            
            # get top k words and corresponding probabilities
            p, top_word = output.topk(top_k)
            # if using gpu           
            p = p.cpu()
            
            # sample from top k words to get next word
            p = p.detach().squeeze().numpy()
            top_word = torch.squeeze(top_word)
            
            word = np.random.choice(top_word, p = p/p.sum())
            
            # add word to sequence
            out_seq[seed_len+t] = word
            
            # encode predicted word to one-hot encoding for next step
            word = to_categorical(word, num_classes=self.vocab_size)
            word = torch.from_numpy(word).unsqueeze(0)
            # if using gpu
            word = word.to(device)
            
        return out_seq

# %%
def get_batches(arr, n_seqs, n_words):
    """
        create generator object that returns batches of input (x) and target (y).
        x of each batch has shape 128*128*149 (batch_size*seq_len*vocab_size).
        
        accepts 3 arguments:
        1. arr: array of words from text data
        2. n_seq: number of sequence in each batch (aka batch_size)
        3. n_word: number of words in each sequence
    """
    
    # compute total elements / dimension of each batch
    batch_total = n_seqs * n_words
    
    # compute total number of complete batches
    n_batches = arr.size//batch_total
    
    # chop array at the last full batch
    arr = arr[: n_batches* batch_total]
    
    # reshape array to matrix with rows = no. of seq in one batch
    arr = arr.reshape((n_seqs, -1))
    
    # for each n_words in every row of the dataset
    for n in range(0, arr.shape[1], n_words):
        
        # chop it vertically, to get the input sequences
        x = arr[:, n:n+n_words]
        
        # init y - target with shape same as x
        y = np.zeros_like(x)
        
        # targets obtained by shifting by one
        try:
            y[:, :-1], y[:, -1] = x[:, 1:], x[:, n+n_words]
        except IndexError:
            y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
        
        # yield function is like return, but creates a generator object
        yield x, y

# %%
# compile the network - sequence_len, vocab_size, hidden_dim, batch_size
net = WordLSTM(sequence_len=512, vocab_size=len(word2int), hidden_dim=512, batch_size=128)
# if using gpu
net.to(device)

# define the loss and the optimizer
optimizer = optim.Adam(net.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# split dataset into 90% train and 10% using index
val_idx = int(len(encoded) * (1 - 0.1))
train_data, val_data = encoded[:val_idx], encoded[val_idx:]

# empty list for the validation losses
val_losses = list()

# empty list for the samples
samples = list()

# %%
for i, (x,y) in enumerate(get_batches(train_data, 128, 512)):
    print(i,(x,y))

# %%
for i in net.parameters():
    print(i)

# %%
# track time
start_time = time.time()

# declare seed sequence
#seed_string = "p47 p50 wait8 endp47 endp50 wait4 p47 p50 wait8 endp47 endp50"

# finally train the model
for epoch in range(50):
    
    # init the hidden and cell states to zero
    hc = net.init_hidden()
    
    # (x, y) refers to one batch with index i, where x is input, y is target
    for i, (x, y) in enumerate(get_batches(train_data, 128, 512)):
        
        # get the torch tensors from the one-hot of training data
        # also transpose the axis for the training set and the targets
        x_train = torch.from_numpy(to_categorical(x, num_classes=net.vocab_size).transpose([1, 0, 2]))
        targets = torch.from_numpy(y.T).type(torch.LongTensor)  # tensor of the target
        
        # if using gpu
        x_train = x_train.to(device)
        targets = targets.to(device)
        
        # zero out the gradients
        optimizer.zero_grad()
        
        # get the output sequence from the input and the initial hidden and cell states
        # calls forward function
        output = net(x_train, hc)
    
        # calculate the loss
        # we need to calculate the loss across all batches, so we have to flat the targets tensor
        loss = criterion(output, targets.contiguous().view(128*512))
        
        # calculate the gradients
        loss.backward()
        
        # update the parameters of the model
        optimizer.step()
        
        # track time
    
        # feedback every 100 batches
        if i % 100 == 0:
            
            # initialize the validation hidden state and cell state
            val_h, val_c = net.init_hidden()
            
            for val_x, val_y in get_batches(val_data, 128, 512):
        
                # prepare the validation inputs and targets
                val_x = torch.from_numpy(to_categorical(val_x).transpose([1, 0, 2]))
                val_y = torch.from_numpy(val_y.T).type(torch.LongTensor).contiguous().view(128*512)
  
                # if using gpu
                val_x = val_x.to(device)
                val_y = val_y.to(device)
            
                # get the validation output
                val_output = net(val_x, (val_h, val_c))
                
                # get the validation loss
                val_loss = criterion(val_output, val_y)
                
                # append the validation loss
                val_losses.append(val_loss.item())
                 
                # samples.append(''.join([int2char[int_] for int_ in net.predict("p33", seq_len=1024)]))
                
            #with open("training_output/loss/loss_epoch" + str(epoch) + "_batch" + str(i) + ".txt", "w") as loss_file:
            #    loss_file.write("Epoch: {}, Batch: {}, Train Loss: {:.6f}, Validation Loss: {:.6f}".format(epoch, i, loss.item(), val_loss.item()))

            with open("training_output/samples/beethoven_2/result_epoch" + str(epoch) + "_batch" + str(i) + ".txt", "w") as outfile:
                outfile.write(' '.join([int2word[int_] for int_ in net.predict('p33', pred_len=512)]))
        
            # track time
            duration = round(time.time() - start_time, 1)
            start_time = time.time()
    
            #print("Epoch: {}, Batch: {}, Duration: {} sec".format(epoch, i, duration))
            print("Epoch: {}, Batch: {}, Duration: {} sec, Train Loss: {:.6f}, Validation Loss: {:.6f}".format(epoch, i, duration, loss.item(), val_loss.item()))

    # save model every 5 epochs
    if epoch % 5 == 0:
        torch.save(net, 'models/beethoven_2/lstm' + str(epoch))
# Out:
# Epoch: 0, Batch: 0, Duration: 11.4 sec, Train Loss: 5.002234, Validation Loss: 4.978434
# Epoch: 0, Batch: 100, Duration: 78.4 sec, Train Loss: 4.060242, Validation Loss: 4.235833
# Epoch: 0, Batch: 200, Duration: 78.6 sec, Train Loss: 3.276564, Validation Loss: 3.489861
# /jet/var/python/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type WordLSTM. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch: 1, Batch: 0, Duration: 38.2 sec, Train Loss: 3.091501, Validation Loss: 3.317040
# Epoch: 1, Batch: 100, Duration: 78.8 sec, Train Loss: 2.767900, Validation Loss: 2.905946
# Epoch: 1, Batch: 200, Duration: 78.7 sec, Train Loss: 2.069426, Validation Loss: 2.284524
# Epoch: 2, Batch: 0, Duration: 38.2 sec, Train Loss: 1.954763, Validation Loss: 2.176536
# Epoch: 2, Batch: 100, Duration: 78.8 sec, Train Loss: 1.828510, Validation Loss: 1.958728
# Epoch: 2, Batch: 200, Duration: 78.9 sec, Train Loss: 1.626389, Validation Loss: 1.825653
# Epoch: 3, Batch: 0, Duration: 38.3 sec, Train Loss: 1.569928, Validation Loss: 1.784570
# Epoch: 3, Batch: 100, Duration: 78.7 sec, Train Loss: 1.561190, Validation Loss: 1.715462
# Epoch: 3, Batch: 200, Duration: 79.0 sec, Train Loss: 1.439928, Validation Loss: 1.659873
# Epoch: 4, Batch: 0, Duration: 38.3 sec, Train Loss: 1.392178, Validation Loss: 1.638775
# Epoch: 4, Batch: 100, Duration: 79.1 sec, Train Loss: 1.410460, Validation Loss: 1.612470
# Epoch: 4, Batch: 200, Duration: 78.6 sec, Train Loss: 1.315634, Validation Loss: 1.580821
# Epoch: 5, Batch: 0, Duration: 38.3 sec, Train Loss: 1.273098, Validation Loss: 1.569334
# Epoch: 5, Batch: 100, Duration: 78.7 sec, Train Loss: 1.307684, Validation Loss: 1.553446
# Epoch: 5, Batch: 200, Duration: 79.0 sec, Train Loss: 1.227004, Validation Loss: 1.532673
# Epoch: 6, Batch: 0, Duration: 38.4 sec, Train Loss: 1.185338, Validation Loss: 1.525136
# Epoch: 6, Batch: 100, Duration: 78.9 sec, Train Loss: 1.225335, Validation Loss: 1.517718
# Epoch: 6, Batch: 200, Duration: 79.0 sec, Train Loss: 1.155635, Validation Loss: 1.503096
# Epoch: 7, Batch: 0, Duration: 38.4 sec, Train Loss: 1.114907, Validation Loss: 1.497009
# Epoch: 7, Batch: 100, Duration: 79.2 sec, Train Loss: 1.156097, Validation Loss: 1.500520
# Epoch: 7, Batch: 200, Duration: 78.8 sec, Train Loss: 1.096367, Validation Loss: 1.485567
# Epoch: 8, Batch: 0, Duration: 38.3 sec, Train Loss: 1.056837, Validation Loss: 1.486229
# Epoch: 8, Batch: 100, Duration: 79.0 sec, Train Loss: 1.096192, Validation Loss: 1.488600
# Epoch: 8, Batch: 200, Duration: 79.0 sec, Train Loss: 1.043329, Validation Loss: 1.477800
# Epoch: 9, Batch: 0, Duration: 38.3 sec, Train Loss: 1.005414, Validation Loss: 1.486341
# Epoch: 9, Batch: 100, Duration: 78.8 sec, Train Loss: 1.048304, Validation Loss: 1.495180
# Epoch: 9, Batch: 200, Duration: 79.2 sec, Train Loss: 1.008899, Validation Loss: 1.490608
# Epoch: 10, Batch: 0, Duration: 38.4 sec, Train Loss: 0.961481, Validation Loss: 1.491058
# Epoch: 10, Batch: 100, Duration: 79.1 sec, Train Loss: 1.000915, Validation Loss: 1.495652
# Epoch: 10, Batch: 200, Duration: 79.5 sec, Train Loss: 0.954656, Validation Loss: 1.489127
# Epoch: 11, Batch: 0, Duration: 38.4 sec, Train Loss: 0.916063, Validation Loss: 1.502928
# Epoch: 11, Batch: 100, Duration: 79.3 sec, Train Loss: 0.954712, Validation Loss: 1.507817
# Epoch: 11, Batch: 200, Duration: 79.5 sec, Train Loss: 0.915833, Validation Loss: 1.502349
# Epoch: 12, Batch: 0, Duration: 38.4 sec, Train Loss: 0.876552, Validation Loss: 1.517453
# Epoch: 12, Batch: 100, Duration: 79.4 sec, Train Loss: 0.911272, Validation Loss: 1.529269
# Epoch: 12, Batch: 200, Duration: 79.1 sec, Train Loss: 0.880031, Validation Loss: 1.526860
# Epoch: 13, Batch: 0, Duration: 41.6 sec, Train Loss: 0.839079, Validation Loss: 1.534062
# Epoch: 13, Batch: 100, Duration: 84.5 sec, Train Loss: 0.874122, Validation Loss: 1.547542
# Epoch: 13, Batch: 200, Duration: 78.7 sec, Train Loss: 0.843194, Validation Loss: 1.554901
# Epoch: 14, Batch: 0, Duration: 38.3 sec, Train Loss: 0.805843, Validation Loss: 1.551373
# Epoch: 14, Batch: 100, Duration: 78.8 sec, Train Loss: 0.845123, Validation Loss: 1.568854
# Epoch: 14, Batch: 200, Duration: 79.0 sec, Train Loss: 0.811182, Validation Loss: 1.586048
# Epoch: 15, Batch: 0, Duration: 38.3 sec, Train Loss: 0.775480, Validation Loss: 1.578737
# Epoch: 15, Batch: 100, Duration: 79.0 sec, Train Loss: 0.811224, Validation Loss: 1.603218
# Epoch: 15, Batch: 200, Duration: 79.2 sec, Train Loss: 0.785810, Validation Loss: 1.607511
# Epoch: 16, Batch: 0, Duration: 38.5 sec, Train Loss: 0.745474, Validation Loss: 1.611982
# Epoch: 16, Batch: 100, Duration: 79.4 sec, Train Loss: 0.784569, Validation Loss: 1.645234
# Epoch: 16, Batch: 200, Duration: 79.3 sec, Train Loss: 0.753516, Validation Loss: 1.641085
# Epoch: 17, Batch: 0, Duration: 38.5 sec, Train Loss: 0.717032, Validation Loss: 1.649566
# Epoch: 17, Batch: 100, Duration: 78.9 sec, Train Loss: 0.758290, Validation Loss: 1.673601
# Epoch: 17, Batch: 200, Duration: 79.1 sec, Train Loss: 0.731796, Validation Loss: 1.679130
# Epoch: 18, Batch: 0, Duration: 38.4 sec, Train Loss: 0.715579, Validation Loss: 1.683819
# Epoch: 18, Batch: 100, Duration: 79.1 sec, Train Loss: 0.733909, Validation Loss: 1.694032
# Epoch: 18, Batch: 200, Duration: 79.1 sec, Train Loss: 0.709117, Validation Loss: 1.716813
# Epoch: 19, Batch: 0, Duration: 38.3 sec, Train Loss: 0.675486, Validation Loss: 1.710424
# Epoch: 19, Batch: 100, Duration: 79.3 sec, Train Loss: 0.702898, Validation Loss: 1.720945
# Epoch: 19, Batch: 200, Duration: 79.0 sec, Train Loss: 0.685710, Validation Loss: 1.748741
# Epoch: 20, Batch: 0, Duration: 38.2 sec, Train Loss: 0.650266, Validation Loss: 1.747686
# Epoch: 20, Batch: 100, Duration: 78.8 sec, Train Loss: 0.679261, Validation Loss: 1.770951
# Epoch: 20, Batch: 200, Duration: 79.1 sec, Train Loss: 0.665981, Validation Loss: 1.773724
# Epoch: 21, Batch: 0, Duration: 38.4 sec, Train Loss: 0.629601, Validation Loss: 1.783242
# Epoch: 21, Batch: 100, Duration: 79.1 sec, Train Loss: 0.659887, Validation Loss: 1.812126
# Epoch: 21, Batch: 200, Duration: 79.2 sec, Train Loss: 0.647552, Validation Loss: 1.802591
# Epoch: 22, Batch: 0, Duration: 38.2 sec, Train Loss: 0.610616, Validation Loss: 1.823526
# Epoch: 22, Batch: 100, Duration: 79.4 sec, Train Loss: 0.639113, Validation Loss: 1.837086
# Epoch: 22, Batch: 200, Duration: 79.1 sec, Train Loss: 0.623715, Validation Loss: 1.835408
# Epoch: 23, Batch: 0, Duration: 38.4 sec, Train Loss: 0.592453, Validation Loss: 1.863334
# Epoch: 23, Batch: 100, Duration: 79.3 sec, Train Loss: 0.625068, Validation Loss: 1.868902
# Epoch: 23, Batch: 200, Duration: 79.1 sec, Train Loss: 0.610634, Validation Loss: 1.871084
# Epoch: 24, Batch: 0, Duration: 38.6 sec, Train Loss: 0.577495, Validation Loss: 1.891387
# Epoch: 24, Batch: 100, Duration: 79.1 sec, Train Loss: 0.612075, Validation Loss: 1.921974
# Epoch: 24, Batch: 200, Duration: 79.5 sec, Train Loss: 0.601545, Validation Loss: 1.914652
# Epoch: 25, Batch: 0, Duration: 38.7 sec, Train Loss: 0.567740, Validation Loss: 1.926014
# Epoch: 25, Batch: 100, Duration: 79.2 sec, Train Loss: 0.594533, Validation Loss: 1.956988
# Epoch: 25, Batch: 200, Duration: 79.2 sec, Train Loss: 0.584411, Validation Loss: 1.953535
# Epoch: 26, Batch: 0, Duration: 38.4 sec, Train Loss: 0.559535, Validation Loss: 1.963664
# Epoch: 26, Batch: 100, Duration: 79.0 sec, Train Loss: 0.581997, Validation Loss: 1.967802
# Epoch: 26, Batch: 200, Duration: 78.9 sec, Train Loss: 0.566708, Validation Loss: 1.981639
# Epoch: 27, Batch: 0, Duration: 38.4 sec, Train Loss: 0.542437, Validation Loss: 2.013296
# Epoch: 27, Batch: 100, Duration: 79.3 sec, Train Loss: 0.563966, Validation Loss: 2.008010
# Epoch: 27, Batch: 200, Duration: 79.5 sec, Train Loss: 0.560077, Validation Loss: 2.011321
# Epoch: 28, Batch: 0, Duration: 38.4 sec, Train Loss: 0.529961, Validation Loss: 2.031457
# Epoch: 28, Batch: 100, Duration: 79.1 sec, Train Loss: 0.551319, Validation Loss: 2.039293
# Epoch: 28, Batch: 200, Duration: 79.2 sec, Train Loss: 0.536946, Validation Loss: 2.060806
# Epoch: 29, Batch: 0, Duration: 38.4 sec, Train Loss: 0.513162, Validation Loss: 2.071025
# Epoch: 29, Batch: 100, Duration: 79.2 sec, Train Loss: 0.541710, Validation Loss: 2.074715
# Epoch: 29, Batch: 200, Duration: 79.4 sec, Train Loss: 0.554802, Validation Loss: 2.074091
# Epoch: 30, Batch: 0, Duration: 38.4 sec, Train Loss: 0.517378, Validation Loss: 2.074801
# Epoch: 30, Batch: 100, Duration: 79.1 sec, Train Loss: 0.531759, Validation Loss: 2.110302
# Epoch: 30, Batch: 200, Duration: 79.2 sec, Train Loss: 0.518418, Validation Loss: 2.119463
# Epoch: 31, Batch: 0, Duration: 38.6 sec, Train Loss: 0.491857, Validation Loss: 2.137560
# Epoch: 31, Batch: 100, Duration: 79.4 sec, Train Loss: 0.550838, Validation Loss: 2.156544
# Epoch: 31, Batch: 200, Duration: 79.1 sec, Train Loss: 0.512441, Validation Loss: 2.127385
# Epoch: 32, Batch: 0, Duration: 38.3 sec, Train Loss: 0.481189, Validation Loss: 2.173853
# Epoch: 32, Batch: 100, Duration: 79.3 sec, Train Loss: 0.507572, Validation Loss: 2.185253
# Epoch: 32, Batch: 200, Duration: 78.3 sec, Train Loss: 0.500582, Validation Loss: 2.161828
# Epoch: 33, Batch: 0, Duration: 37.6 sec, Train Loss: 0.468401, Validation Loss: 2.220862
# Epoch: 33, Batch: 100, Duration: 79.0 sec, Train Loss: 0.507744, Validation Loss: 2.214358
# Epoch: 33, Batch: 200, Duration: 79.4 sec, Train Loss: 0.494570, Validation Loss: 2.183249
# Epoch: 34, Batch: 0, Duration: 38.5 sec, Train Loss: 0.462069, Validation Loss: 2.243927
# Epoch: 34, Batch: 100, Duration: 79.5 sec, Train Loss: 0.492392, Validation Loss: 2.243418
# Epoch: 34, Batch: 200, Duration: 79.2 sec, Train Loss: 0.482398, Validation Loss: 2.217270
# Epoch: 35, Batch: 0, Duration: 38.5 sec, Train Loss: 0.452804, Validation Loss: 2.278739
# Epoch: 35, Batch: 100, Duration: 79.4 sec, Train Loss: 0.477649, Validation Loss: 2.286511
# Epoch: 35, Batch: 200, Duration: 79.1 sec, Train Loss: 0.472671, Validation Loss: 2.253354
# Epoch: 36, Batch: 0, Duration: 38.6 sec, Train Loss: 0.446754, Validation Loss: 2.300774
# Epoch: 36, Batch: 100, Duration: 79.4 sec, Train Loss: 0.470579, Validation Loss: 2.318309
# Epoch: 36, Batch: 200, Duration: 79.5 sec, Train Loss: 0.468710, Validation Loss: 2.315927
# Epoch: 37, Batch: 0, Duration: 38.6 sec, Train Loss: 0.440447, Validation Loss: 2.320284
# Epoch: 37, Batch: 100, Duration: 79.3 sec, Train Loss: 0.466389, Validation Loss: 2.349508
# Epoch: 37, Batch: 200, Duration: 79.1 sec, Train Loss: 0.454435, Validation Loss: 2.342456
# Epoch: 38, Batch: 0, Duration: 38.3 sec, Train Loss: 0.433583, Validation Loss: 2.337886
# Epoch: 38, Batch: 100, Duration: 79.0 sec, Train Loss: 0.455285, Validation Loss: 2.386173
# Epoch: 38, Batch: 200, Duration: 78.8 sec, Train Loss: 0.445409, Validation Loss: 2.348966
# Epoch: 39, Batch: 0, Duration: 38.5 sec, Train Loss: 0.426883, Validation Loss: 2.364719
# Epoch: 39, Batch: 100, Duration: 79.0 sec, Train Loss: 0.449060, Validation Loss: 2.398841
# Epoch: 39, Batch: 200, Duration: 79.0 sec, Train Loss: 0.437169, Validation Loss: 2.381572
# Epoch: 40, Batch: 0, Duration: 38.4 sec, Train Loss: 0.417207, Validation Loss: 2.416956
# Epoch: 40, Batch: 100, Duration: 79.4 sec, Train Loss: 0.441855, Validation Loss: 2.419650
# Epoch: 40, Batch: 200, Duration: 79.2 sec, Train Loss: 0.432660, Validation Loss: 2.431563
# Epoch: 41, Batch: 0, Duration: 38.4 sec, Train Loss: 0.406371, Validation Loss: 2.454154
# Epoch: 41, Batch: 100, Duration: 78.9 sec, Train Loss: 0.432635, Validation Loss: 2.440049
# Epoch: 41, Batch: 200, Duration: 79.0 sec, Train Loss: 0.431645, Validation Loss: 2.477066
# Epoch: 42, Batch: 0, Duration: 38.3 sec, Train Loss: 0.402233, Validation Loss: 2.472245
# Epoch: 42, Batch: 100, Duration: 79.0 sec, Train Loss: 0.424571, Validation Loss: 2.470746
# Epoch: 42, Batch: 200, Duration: 78.9 sec, Train Loss: 0.417780, Validation Loss: 2.512135
# Epoch: 43, Batch: 0, Duration: 38.4 sec, Train Loss: 0.400599, Validation Loss: 2.479351
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b447535fbe44> in <module>()
#      28         # get the output sequence from the input and the initial hidden and cell states
#      29         # calls forward function
# ---> 30         output = net(x_train, hc)
#      31
#      32         # calculate the loss
#
# ~/var/python/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# <ipython-input-5-e15692b2601c> in forward(self, x, hc)
#      47
#      48             # layer 1 lstm
# ---> 49             hc_1 = self.lstm_1(x[t], hc_1)
#      50             h_1, c_1 = hc_1
#      51
#
# ~/var/python/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/var/python/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     711             input, hx,
#     712             self.weight_ih, self.weight_hh,
# --> 713             self.bias_ih, self.bias_hh,
#     714         )
#     715
#
# ~/var/python/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in LSTMCell(input, hidden, w_ih, w_hh, b_ih, b_hh)
#      26 def LSTMCell(input, hidden, w_ih, w_hh, b_ih=None, b_hh=None):
#      27     if input.is_cuda:
# ---> 28         igates = F.linear(input, w_ih)
#      29         hgates = F.linear(hidden[0], w_hh)
#      30         state = fusedBackend.LSTMFused.apply
#
# ~/var/python/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1024         return torch.addmm(bias, input, weight.t())
#    1025
# -> 1026     output = input.matmul(weight.t())
#    1027     if bias is not None:
#    1028         output += bias
#
# KeyboardInterrupt:

# %%
loaded_model = torch.load('../models/lstm' + str(epoch))
