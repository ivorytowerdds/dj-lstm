# %%
## this version is for the format: e.g. 1P22, 1endp22

import numpy as np
from math import floor
import music21
import re
import os

def get_file(txt):
    with open(txt, 'r') as file:
        string = file.read()
        return string

def arrToStreamChordwise(score, sample_freq, note_offset):
    # define variables and lists needed for chord decoding
    speed = 1./sample_freq
    piano_notes = []
    violin_notes = []
    time_offset = 0

    for i in range(len(score)):
        # skip empty lists
        if len(score[i]) == 0:
            continue

        # skip idx 0 as it indicates instruments
        for j in range(1, len(score[i])):

            # if the note is played, append note to list
            if score[i][j] == "1":
                duration=2

                # create music21 note object
                new_note = music21.note.Note(j + note_offset)

                # add duration to note object
                new_note.duration = music21.duration.Duration(duration * speed)

                # add timestamp (time offset) to note object
                new_note.offset = (i + time_offset) * speed


                # append note to respective instruments
                if score[i][0] == 'p':
                    piano_notes.append(new_note)
                elif score[i][0] == 'v':
                    violin_notes.append(new_note)

    # list of all notes for each instrument should be ready at this stage

    # creating music21 instrument objects
    violin = music21.instrument.fromString("Violin")
    piano = music21.instrument.fromString("Piano")

    # insert instrument object to start (0 index) of notes list
    violin_notes.insert(0, violin)
    piano_notes.insert(0, piano)

    # create music21 stream object for individual instruments
    violin_stream = music21.stream.Stream(violin_notes)
    piano_stream = music21.stream.Stream(piano_notes)

    # merge both stream objects into a single stream of 2 instruments
    chord_stream = music21.stream.Stream([violin_stream, piano_stream])
    #chord_stream.insert(0.0,music21.tempo.MetronomeMark('maestoso',tempo))
    
    return chord_stream

def arrToStreamNotewise(score, sample_freq, note_offset):    
    # define variables and lists needed for chord decoding
    speed = 1./sample_freq
    piano_notes = []
    violin_notes = []
    time_offset = 0
    
    i = 0
    while i < len(score):
        if score[i][0:9] == "p_octave_":
            add_wait=""
            if score[i][-3:] == "eoc":
                add_wait = "eoc"
                score[i] = score[i][:-3]
            this_note = score[i][9:]
            score[i] = "p"+this_note
            score.insert(i+1, "p" + str(int(this_note) + 12) + add_wait)
            i += 1
        i += 1

    for i in range(len(score)):
        if score[i] in ["", " ", "<eos>", "<unk>"]:
            continue
        elif score[i][0:3] == "end":
            if score[i][-3:] == "eoc":
                time_offset += 1
            continue
        elif score[i][:4] == "wait":
            time_offset += int(score[i][4:])
            continue
        else:
            # Look ahead to see if an end<noteid> was generated
            # soon after.  
            duration = 1
            has_end = False
            note_string_len = len(score[i])
            for j in range(1, 200):
                if i+j == len(score):
                    break
                if score[i+j][:4] == "wait":
                    duration += int(score[i+j][4:])
                if score[i+j][:3+note_string_len] == "end" + score[i] or score[i+j]==score[i]:
                    has_end = True
                    break
                if score[i+j][-3:] == "eoc":
                    duration += 1

            if not has_end:
                duration = 12

            add_wait = 0
            if score[i][-3:] == "eoc":
                score[i] = score[i][:-3]
                add_wait = 1

            try: 
                new_note = music21.note.Note(int(score[i][1:]) + note_offset)    
                new_note.duration = music21.duration.Duration(duration * speed)
                new_note.offset = time_offset*speed
                if score[i][0] == "v":
                    violin_notes.append(new_note)
                else:
                    piano_notes.append(new_note)                
            except:
                print("Unknown note: " + score[i])
                
            time_offset += add_wait


    # list of all notes for each instrument should be ready at this stage

    # creating music21 instrument objects      
    violin = music21.instrument.fromString("Violin")
    piano = music21.instrument.fromString("Piano")

    # insert instrument object to start (0 index) of notes list
    violin_notes.insert(0, violin)
    piano_notes.insert(0, piano)

    # create music21 stream object for individual instruments
    violin_stream = music21.stream.Stream(violin_notes)
    piano_stream = music21.stream.Stream(piano_notes)

    # merge both stream objects into a single stream of 2 instruments
    note_stream = music21.stream.Stream([violin_stream, piano_stream])

    # add tempo
    #note_stream.insert(0.0,music21.tempo.MetronomeMark('Larghetto', tempo))

    return note_stream

def write_midi(s, filename, output_folder):
    fp = s.write('midi', fp=output_folder+filename+".mid")
    
def decoding_music(notetxt,notename,sample_freq,note_offset):
    #chordstring = get_file(chordtxt)
    notestring = get_file(notetxt)
    
    #score_chord = chordstring.split(" ")
    score_note = notestring.split(" ")
    
    #chord_stream = arrToStreamChordwise(score_chord, sample_freq, note_offset, tempo)
    note_stream = arrToStreamNotewise(score_note, sample_freq, note_offset)

    pattern = re.compile('.*?/.*?/.*?/(.*?).txt')
    #chordname = re.findall(pattern, chordtxt)[0]
    notename = re.findall(pattern, notetxt)[0]
    
    #write_midi(chord_stream, chordname, chord_output)
    write_midi(note_stream, notename, note_output)
    

#note_output = "output_midi/Requiem/"
#notetxt = 'Requiem/lacrimosa_finished_20epoch.txt'
#sample_freq = 12
#note_offset = 33
#tempo = 80
#decoding_music(notetxt, note_output, sample_freq, note_offset, tempo)

# %%
import os
txtfiles = os.listdir('training_output/samples/mozart')
txtfiles
# Out:
# ['result_epoch35_batch300.txt',
#  'result_epoch36_batch500.txt',
#  'result_epoch0_batch200.txt',
#  'result_epoch3_batch800.txt',
#  'result_epoch19_batch900.txt',
#  'result_epoch35_batch0.txt',
#  'result_epoch16_batch800.txt',
#  'result_epoch39_batch0.txt',
#  'result_epoch39_batch700.txt',
#  'result_epoch6_batch300.txt',
#  'result_epoch23_batch500.txt',
#  'result_epoch20_batch500.txt',
#  'result_epoch5_batch400.txt',
#  'result_epoch13_batch800.txt',
#  'result_epoch3_batch200.txt',
#  'result_epoch39_batch400.txt',
#  'result_epoch13_batch500.txt',
#  'result_epoch19_batch400.txt',
#  'result_epoch17_batch200.txt',
#  'result_epoch36_batch300.txt',
#  'result_epoch0_batch500.txt',
#  'result_epoch8_batch300.txt',
#  'result_epoch10_batch200.txt',
#  'result_epoch9_batch200.txt',
#  'result_epoch30_batch500.txt',
#  'result_epoch18_batch300.txt',
#  'result_epoch21_batch200.txt',
#  'result_epoch3_batch500.txt',
#  'result_epoch33_batch700.txt',
#  'result_epoch27_batch400.txt',
#  'result_epoch31_batch700.txt',
#  'result_epoch35_batch900.txt',
#  'result_epoch36_batch400.txt',
#  'result_epoch20_batch200.txt',
#  'result_epoch2_batch200.txt',
#  'result_epoch26_batch500.txt',
#  'result_epoch30_batch100.txt',
#  'result_epoch30_batch600.txt',
#  'result_epoch28_batch400.txt',
#  'result_epoch20_batch0.txt',
#  'result_epoch20_batch100.txt',
#  'result_epoch2_batch500.txt',
#  'result_epoch4_batch900.txt',
#  'result_epoch27_batch0.txt',
#  'result_epoch15_batch400.txt',
#  'result_epoch24_batch0.txt',
#  'result_epoch15_batch500.txt',
#  'result_epoch33_batch300.txt',
#  'result_epoch31_batch600.txt',
#  'result_epoch15_batch600.txt',
#  'result_epoch26_batch800.txt',
#  'result_epoch23_batch600.txt',
#  'result_epoch25_batch200.txt',
#  'result_epoch28_batch0.txt',
#  'result_epoch38_batch700.txt',
#  'result_epoch32_batch100.txt',
#  'result_epoch22_batch0.txt',
#  'result_epoch23_batch400.txt',
#  'result_epoch28_batch100.txt',
#  'result_epoch18_batch500.txt',
#  'result_epoch5_batch500.txt',
#  'result_epoch21_batch600.txt',
#  'result_epoch36_batch0.txt',
#  'result_epoch11_batch600.txt',
#  'result_epoch31_batch100.txt',
#  'result_epoch25_batch900.txt',
#  'result_epoch19_batch700.txt',
#  'result_epoch35_batch600.txt',
#  'result_epoch35_batch700.txt',
#  'result_epoch16_batch200.txt',
#  'result_epoch9_batch500.txt',
#  'result_epoch0_batch800.txt',
#  'result_epoch12_batch300.txt',
#  'result_epoch16_batch500.txt',
#  'result_epoch28_batch300.txt',
#  'result_epoch12_batch600.txt',
#  'result_epoch28_batch800.txt',
#  'result_epoch39_batch100.txt',
#  'result_epoch24_batch700.txt',
#  'result_epoch34_batch600.txt',
#  'result_epoch1_batch700.txt',
#  'result_epoch4_batch800.txt',
#  'result_epoch28_batch200.txt',
#  'result_epoch23_batch800.txt',
#  'result_epoch20_batch900.txt',
#  'result_epoch32_batch300.txt',
#  'result_epoch30_batch300.txt',
#  'result_epoch0_batch0.txt',
#  'result_epoch12_batch0.txt',
#  'result_epoch0_batch900.txt',
#  'result_epoch14_batch600.txt',
#  'result_epoch19_batch200.txt',
#  'result_epoch32_batch900.txt',
#  'result_epoch24_batch900.txt',
#  'result_epoch11_batch400.txt',
#  'result_epoch10_batch100.txt',
#  'result_epoch17_batch900.txt',
#  'result_epoch31_batch200.txt',
#  'result_epoch6_batch500.txt',
#  'result_epoch25_batch500.txt',
#  'result_epoch7_batch600.txt',
#  'result_epoch3_batch700.txt',
#  'result_epoch27_batch200.txt',
#  'result_epoch34_batch900.txt',
#  'result_epoch12_batch500.txt',
#  'result_epoch29_batch900.txt',
#  'result_epoch8_batch500.txt',
#  'result_epoch3_batch100.txt',
#  'result_epoch21_batch400.txt',
#  'result_epoch34_batch100.txt',
#  'result_epoch17_batch100.txt',
#  'result_epoch3_batch900.txt',
#  'result_epoch15_batch0.txt',
#  'result_epoch16_batch0.txt',
#  'result_epoch24_batch800.txt',
#  'result_epoch29_batch700.txt',
#  'result_epoch22_batch400.txt',
#  'result_epoch17_batch400.txt',
#  'result_epoch4_batch100.txt',
#  'result_epoch7_batch900.txt',
#  'result_epoch38_batch200.txt',
#  'result_epoch24_batch100.txt',
#  'result_epoch21_batch100.txt',
#  'result_epoch32_batch400.txt',
#  'result_epoch11_batch100.txt',
#  'result_epoch14_batch300.txt',
#  'result_epoch14_batch800.txt',
#  'result_epoch33_batch900.txt',
#  'result_epoch14_batch900.txt',
#  'result_epoch7_batch800.txt',
#  'result_epoch0_batch700.txt',
#  'result_epoch26_batch400.txt',
#  'result_epoch23_batch300.txt',
#  'result_epoch0_batch600.txt',
#  'result_epoch9_batch100.txt',
#  'result_epoch30_batch200.txt',
#  'result_epoch1_batch600.txt',
#  'result_epoch8_batch100.txt',
#  'result_epoch33_batch800.txt',
#  'result_epoch17_batch700.txt',
#  'result_epoch35_batch400.txt',
#  'result_epoch9_batch400.txt',
#  'result_epoch16_batch600.txt',
#  'result_epoch18_batch400.txt',
#  'result_epoch13_batch300.txt',
#  'result_epoch13_batch600.txt',
#  'result_epoch11_batch500.txt',
#  'result_epoch14_batch200.txt',
#  'result_epoch39_batch600.txt',
#  'result_epoch2_batch800.txt',
#  'result_epoch6_batch600.txt',
#  'result_epoch37_batch800.txt',
#  'result_epoch14_batch400.txt',
#  'result_epoch8_batch600.txt',
#  'result_epoch2_batch300.txt',
#  'result_epoch31_batch300.txt',
#  'result_epoch25_batch800.txt',
#  'result_epoch21_batch0.txt',
#  'result_epoch18_batch800.txt',
#  'result_epoch24_batch600.txt',
#  'result_epoch26_batch0.txt',
#  'result_epoch18_batch100.txt',
#  'result_epoch32_batch700.txt',
#  'result_epoch5_batch100.txt',
#  'result_epoch5_batch200.txt',
#  'result_epoch16_batch900.txt',
#  'result_epoch2_batch400.txt',
#  'result_epoch2_batch900.txt',
#  'result_epoch18_batch200.txt',
#  'result_epoch14_batch0.txt',
#  'result_epoch7_batch500.txt',
#  'result_epoch12_batch400.txt',
#  'result_epoch6_batch200.txt',
#  'result_epoch34_batch700.txt',
#  'result_epoch7_batch0.txt',
#  'result_epoch30_batch800.txt',
#  'result_epoch26_batch700.txt',
#  'result_epoch11_batch0.txt',
#  'result_epoch14_batch500.txt',
#  'result_epoch24_batch400.txt',
#  'result_epoch36_batch800.txt',
#  'result_epoch23_batch200.txt',
#  'result_epoch26_batch900.txt',
#  'result_epoch1_batch100.txt',
#  'result_epoch38_batch0.txt',
#  'result_epoch37_batch0.txt',
#  'result_epoch29_batch0.txt',
#  'result_epoch13_batch700.txt',
#  'result_epoch2_batch700.txt',
#  'result_epoch17_batch800.txt',
#  'result_epoch29_batch600.txt',
#  'result_epoch10_batch400.txt',
#  'result_epoch36_batch700.txt',
#  'result_epoch7_batch400.txt',
#  'result_epoch32_batch600.txt',
#  'result_epoch11_batch200.txt',
#  'result_epoch8_batch900.txt',
#  'result_epoch5_batch0.txt',
#  'result_epoch13_batch100.txt',
#  'result_epoch36_batch100.txt',
#  'result_epoch9_batch900.txt',
#  'result_epoch27_batch900.txt',
#  'result_epoch37_batch400.txt',
#  'result_epoch25_batch600.txt',
#  'result_epoch4_batch0.txt',
#  'result_epoch22_batch600.txt',
#  'result_epoch26_batch100.txt',
#  'result_epoch34_batch200.txt',
#  'result_epoch23_batch900.txt',
#  'result_epoch5_batch900.txt',
#  'result_epoch13_batch900.txt',
#  'result_epoch8_batch0.txt',
#  'result_epoch27_batch100.txt',
#  'result_epoch27_batch300.txt',
#  'result_epoch5_batch800.txt',
#  'result_epoch33_batch200.txt',
#  'result_epoch20_batch800.txt',
#  'result_epoch11_batch900.txt',
#  'result_epoch30_batch900.txt',
#  'result_epoch0_batch100.txt',
#  'result_epoch3_batch0.txt',
#  'result_epoch29_batch400.txt',
#  'result_epoch5_batch600.txt',
#  'result_epoch2_batch100.txt',
#  'result_epoch25_batch100.txt',
#  'result_epoch10_batch0.txt',
#  'result_epoch34_batch0.txt',
#  'result_epoch26_batch200.txt',
#  'result_epoch32_batch800.txt',
#  'result_epoch4_batch300.txt',
#  'result_epoch11_batch800.txt',
#  'result_epoch37_batch300.txt',
#  'result_epoch6_batch0.txt',
#  'result_epoch13_batch0.txt',
#  'result_epoch39_batch800.txt',
#  'result_epoch28_batch600.txt',
#  'result_epoch28_batch500.txt',
#  'result_epoch37_batch700.txt',
#  'result_epoch31_batch400.txt',
#  'result_epoch39_batch200.txt',
#  'result_epoch19_batch100.txt',
#  'result_epoch21_batch300.txt',
#  'result_epoch29_batch100.txt',
#  'result_epoch37_batch600.txt',
#  'result_epoch7_batch200.txt',
#  'result_epoch2_batch600.txt',
#  'result_epoch3_batch400.txt',
#  'result_epoch6_batch700.txt',
#  'result_epoch35_batch200.txt',
#  'result_epoch28_batch700.txt',
#  'result_epoch17_batch0.txt',
#  'result_epoch23_batch700.txt',
#  'result_epoch23_batch100.txt',
#  'result_epoch36_batch200.txt',
#  'result_epoch10_batch900.txt',
#  'result_epoch34_batch800.txt',
#  'result_epoch17_batch300.txt',
#  'result_epoch31_batch0.txt',
#  'result_epoch22_batch500.txt',
#  'result_epoch26_batch300.txt',
#  'result_epoch19_batch500.txt',
#  'result_epoch22_batch100.txt',
#  'result_epoch31_batch900.txt',
#  'result_epoch20_batch400.txt',
#  'result_epoch29_batch300.txt',
#  'result_epoch8_batch400.txt',
#  'result_epoch19_batch800.txt',
#  'result_epoch19_batch300.txt',
#  'result_epoch9_batch700.txt',
#  'result_epoch4_batch500.txt',
#  'result_epoch28_batch900.txt',
#  'result_epoch21_batch900.txt',
#  'result_epoch24_batch200.txt',
#  'result_epoch8_batch800.txt',
#  'result_epoch14_batch700.txt',
#  'result_epoch9_batch600.txt',
#  'result_epoch32_batch0.txt',
#  'result_epoch7_batch700.txt',
#  'result_epoch17_batch500.txt',
#  'result_epoch23_batch0.txt',
#  'result_epoch20_batch300.txt',
#  'result_epoch12_batch100.txt',
#  'result_epoch5_batch700.txt',
#  'result_epoch37_batch200.txt',
#  'result_epoch11_batch700.txt',
#  'result_epoch37_batch100.txt',
#  'result_epoch18_batch0.txt',
#  'result_epoch10_batch700.txt',
#  'result_epoch1_batch800.txt',
#  'result_epoch13_batch200.txt',
#  'result_epoch6_batch400.txt',
#  'result_epoch32_batch500.txt',
#  'result_epoch21_batch800.txt',
#  'result_epoch3_batch300.txt',
#  'result_epoch5_batch300.txt',
#  'result_epoch0_batch400.txt',
#  'result_epoch38_batch400.txt',
#  'result_epoch31_batch500.txt',
#  'result_epoch38_batch900.txt',
#  'result_epoch15_batch800.txt',
#  'result_epoch16_batch700.txt',
#  'result_epoch10_batch800.txt',
#  'result_epoch6_batch100.txt',
#  'result_epoch35_batch100.txt',
#  'result_epoch15_batch200.txt',
#  'result_epoch27_batch700.txt',
#  'result_epoch39_batch300.txt',
#  'result_epoch34_batch500.txt',
#  'result_epoch33_batch600.txt',
#  'result_epoch30_batch400.txt',
#  'result_epoch15_batch900.txt',
#  'result_epoch17_batch600.txt',
#  'result_epoch9_batch800.txt',
#  'result_epoch25_batch0.txt',
#  'result_epoch15_batch300.txt',
#  'result_epoch7_batch100.txt',
#  'result_epoch19_batch0.txt',
#  'result_epoch35_batch800.txt',
#  'result_epoch12_batch900.txt',
#  'result_epoch9_batch300.txt',
#  'result_epoch33_batch400.txt',
#  'result_epoch33_batch500.txt',
#  'result_epoch4_batch200.txt',
#  'result_epoch29_batch500.txt',
#  'result_epoch39_batch500.txt',
#  'result_epoch38_batch800.txt',
#  'result_epoch29_batch200.txt',
#  'result_epoch34_batch300.txt',
#  'result_epoch38_batch500.txt',
#  'result_epoch21_batch700.txt',
#  'result_epoch10_batch600.txt',
#  'result_epoch15_batch700.txt',
#  'result_epoch4_batch600.txt',
#  'result_epoch31_batch800.txt',
#  'result_epoch10_batch300.txt',
#  'result_epoch22_batch900.txt',
#  'result_epoch15_batch100.txt',
#  'result_epoch22_batch700.txt',
#  'result_epoch4_batch700.txt',
#  'result_epoch20_batch600.txt',
#  'result_epoch18_batch600.txt',
#  'result_epoch9_batch0.txt',
#  'result_epoch39_batch900.txt',
#  'result_epoch27_batch500.txt',
#  'result_epoch12_batch200.txt',
#  'result_epoch18_batch900.txt',
#  'result_epoch33_batch0.txt',
#  'result_epoch30_batch0.txt',
#  'result_epoch1_batch500.txt',
#  'result_epoch24_batch500.txt',
#  'result_epoch18_batch700.txt',
#  'result_epoch16_batch100.txt',
#  'result_epoch1_batch400.txt',
#  'result_epoch1_batch200.txt',
#  'result_epoch1_batch0.txt',
#  'result_epoch6_batch900.txt',
#  'result_epoch36_batch900.txt',
#  'result_epoch0_batch300.txt',
#  'result_epoch25_batch400.txt',
#  'result_epoch35_batch500.txt',
#  'result_epoch29_batch800.txt',
#  'result_epoch6_batch800.txt',
#  'result_epoch38_batch300.txt',
#  'result_epoch1_batch900.txt',
#  'result_epoch3_batch600.txt',
#  'result_epoch14_batch100.txt',
#  'result_epoch36_batch600.txt',
#  'result_epoch27_batch800.txt',
#  'result_epoch22_batch300.txt',
#  'result_epoch25_batch700.txt',
#  'result_epoch22_batch200.txt',
#  'result_epoch32_batch200.txt',
#  'result_epoch8_batch700.txt',
#  'result_epoch38_batch100.txt',
#  'result_epoch10_batch500.txt',
#  'result_epoch33_batch100.txt',
#  'result_epoch34_batch400.txt',
#  'result_epoch30_batch700.txt',
#  'result_epoch25_batch300.txt',
#  'result_epoch21_batch500.txt',
#  'result_epoch13_batch400.txt',
#  'result_epoch24_batch300.txt',
#  'result_epoch1_batch300.txt',
#  'result_epoch16_batch300.txt',
#  'result_epoch20_batch700.txt',
#  'result_epoch37_batch900.txt',
#  'result_epoch27_batch600.txt',
#  'result_epoch37_batch500.txt',
#  'result_epoch22_batch800.txt',
#  'result_epoch8_batch200.txt',
#  'result_epoch12_batch800.txt',
#  'result_epoch19_batch600.txt',
#  'result_epoch7_batch300.txt',
#  'result_epoch11_batch300.txt',
#  'result_epoch12_batch700.txt',
#  'result_epoch4_batch400.txt',
#  'result_epoch26_batch600.txt',
#  'result_epoch16_batch400.txt',
#  'result_epoch38_batch600.txt',
#  'result_epoch2_batch0.txt']

# %%
sample_freq = 12
note_offset = 33
#tempo = 80
txtfiles = os.listdir('training_output/samples/mozart')
note_output = "output_midi/mozart/"
for i in range(len(txtfiles)):
    if txtfiles[i] != '.ipynb_checkpoints':
        notetxt = 'training_output/samples/mozart/'+ txtfiles[i]
        decoding_music(notetxt, note_output, sample_freq, note_offset)
